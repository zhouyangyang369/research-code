# %%
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
city_name = pd.read_excel('/Users/yangyang-z/documents/python/apple_music/城市URL和sql语句.xlsx','Sheet10',
                          usecols=[1],names=None,header=None)
city_means = pd.read_excel('/Users/yangyang-z/documents/music_data_analysis/city_means_0922.xlsx')

y = city_means.values
print(y[:,1:])
kmeans_3 = KMeans(n_clusters=3).fit(y[:,1:])
cluster_label3 = kmeans_3.labels_
cluster_center3 = kmeans_3.cluster_centers_
print(cluster_label3)
#print(cluster_center)
c1 = []
c2 = []
c3 = []
for  city in range(len(city_name)):
    if cluster_label3[city] == 0:
        c1.append(city_name[1][city])
    if cluster_label3[city] == 1:
        c2.append(city_name[1][city])
    if cluster_label3[city] == 2:
        c3.append(city_name[1][city])
print(c1)
print(c2)
print(c3,'\n')

# %%
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
df = pd.read_excel('/Users/yangyang-z/documents/music_data_analysis/city_means_0119.xlsx')
df_col = list(df)
df_col[0] = 'city'
df.columns = df_col
city = df['city'].tolist()
df = df.drop(['mode', 'instrumentalness', 'liveness', 'speechiness', 'key', 'acousticness'], axis = 1)
y = df.values
kmeans_3 = KMeans(n_clusters=3).fit(y[:,1:])
cluster_label3 = kmeans_3.labels_
cluster_center3 = kmeans_3.cluster_centers_
c1 = []
c2 = []
c3 = []
for  i in range(len(city)):
    if cluster_label3[i] == 0:
        c1.append(city[i])
    if cluster_label3[i] == 1:
        c2.append(city[i])
    if cluster_label3[i] == 2:
        c3.append(city[i])
print(c1)
print(c2)
print(c3,'\n')
print(cluster_label3)
# Out:
# ['new_york_city', 'atlanta', 'austin', 'berlin', 'chicago', 'koln', 'dallas', 'denver', 'detroit', 'edmonton', 'frankfurt', 'hamburg', 'houston', 'kingston', 'los_angeles', 'miami', 'mockba', 'munchen', 'nashville', 'ottawa', 'philadelphia', 'phoenix', 'cahkt', 'san_diego', 'san_francisco', 'seattle', 'toronto', 'vancouver', 'wien', 'washington_DC', 'winnipeg', 'zurich_zurich_zurigo']
# ['tokyo', 'osaka', 'nagoya', 'sapporo', 'fukuoka', 'kyoto', 'sendai', 'naha', 'accra', 'barcelona', '北京', 'bogota', 'budapest', 'buenos_aires', 'delhi', 'durban', 'guadalajara', 'istanbul', 'jakarta', 'kuala_lumpur', 'lagos', 'lima', 'madrid', 'medellin', 'monterrey', 'santiago_de_chile', 'santo_domingo', 'テルアビブ']
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker
import os

# 基础数据
value = [95.1, 23.2, 43.3, 66.4, 88.5]
attr = ["China", "Canada", "Brazil", "Russia", "United States"]

data = []
for index in range(len(attr)):
    city_ionfo=[attr[index],value[index]]
    data.append(city_ionfo)

c = (
    Map()
    .add("Word Map",data, "world")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(max_=200),
    )
    .render()
)
c.save
# Out:
# '/Users/yangyang-z/Documents/music_data_analysis/render.html'

# %%
import folium

print(folium.__version__)

# define the world map

world_map = folium.Map()
long_lat = pd.read_excel('/Users/yangyang-z/documents/long_lat_data_export/long_lat的副本.xls')
city = long_lat['city'].tolist()
color = ['grey', 'green', 'orange']
for i in range(len(city)):
    if city[i] in cluster['cluster1']:
        c = color[0]
    elif city[i] in cluster['cluster2']:
        c = color[1]
    else:
        c = color[2]
    l_l = long_lat_dict[city[i]]
    
    folium.Circle(   
        location = l_l, 
        popup=city[i], 
        color=c,
        radius = 100000,
        fill = True
        #icon=folium.Icon(color=c , icon='glyphicon-music' , icon_color='black')
    ).add_to(world_map)
# display world map
world_map
# Out:
# 0.12.1
# ...

# %%
long_lat = pd.read_excel('/Users/yangyang-z/documents/long_lat_data_export/long_lat的副本.xls')
long_lat = long_lat.values.tolist()
long_lat_dict = {}
for i in range(len(long_lat)):
    long_lat_dict[long_lat[i][0]] = [long_lat[i][1], long_lat[i][2]]
long_lat
# Out:
# [['accra', -0.1969, 5.556],
#  ['almaty', 76.95, 43.25],
#  ['lyon', 4.5833, 45.75],
#  ['marseille', 5.5, 43.3333],
#  ['atlanta', -84.388, 33.749],
#  ['auckland', 174.767, -36.8667],
#  ['austin', -97.7431, 30.2672],
#  ['bangkok', 100.517, 13.75],
#  ['barcelona', 2.159, 41.3888],
#  ['北京', 116.397, 39.9075],
#  ['bengaluru', 77.6033, 12.9762],
#  ['berlin', 13.4105, 52.5244],
#  ['birmingham', -86.8025, 33.5207],
#  ['bogota', -74.0817, 4.6097],
#  ['bordeaux', -0.5805, 44.8404],
#  ['brisbane', 153.028, -27.4679],
#  ['budapest', 19.0399, 47.498],
#  ['buenos_aires', -58.3772, -34.6132],
#  ['busan', 129.04, 35.1028],
#  ['calgary', -114.085, 51.0501],
#  ['cape_town', 18.4232, -33.9258],
#  ['chicago', -87.65, 41.85],
#  ['koln', 6.95, 50.9333],
#  ['kobenhavn', 12.5833, 55.6667],
#  ['dallas', -96.7836, 32.7668],
#  ['delhi', 77.2167, 28.6667],
#  ['denver', -104.985, 39.7392],
#  ['detroit', -83.0458, 42.3314],
#  ['dubai', 55.3047, 25.2582],
# ...

# %%
cluster = {}
cluster['cluster1'] = c1
cluster['cluster2'] = c2
cluster['cluster3'] = c3
cluster
# Out:
# {'cluster1': ['new_york_city',
#   'atlanta',
#   'austin',
#   'berlin',
#   'chicago',
#   'koln',
#   'dallas',
#   'denver',
#   'detroit',
#   'edmonton',
#   'frankfurt',
#   'hamburg',
#   'houston',
#   'kingston',
#   'los_angeles',
#   'miami',
#   'mockba',
#   'munchen',
#   'nashville',
#   'ottawa',
#   'philadelphia',
#   'phoenix',
#   'cahkt',
#   'san_diego',
#   'san_francisco',
#   'seattle',
#   'toronto',
#   'vancouver',
#   'wien',
#   'washington_DC',
#   'winnipeg',
#   'zurich_zurich_zurigo'],
#  'cluster2': ['tokyo',
#   'osaka',
#   'nagoya',
#   'sapporo',
#   'fukuoka',
#   'kyoto',
#   'sendai',
#   'naha',
#   'accra',
#   'barcelona',
#   '北京',
#   'bogota',
#   'budapest',
#   'buenos_aires',
#   'delhi',
#   'durban',
#   'guadalajara',
#   'istanbul',
#   'jakarta',
#   'kuala_lumpur',
#   'lagos',
#   'lima',
#   'madrid',
#   'medellin',
#   'monterrey',
#   'santiago_de_chile',
#   'santo_domingo',
#   'テルアビブ'],
#  'cluster3': ['london',
# ...
